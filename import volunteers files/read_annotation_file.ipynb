# %%
import json

data_file = "./downloaded-done/HawaiiBeetles02-Gabriel.json"

with open(data_file, "r") as f:
    data = json.load(f)

print(data[0]["created_at"])
# Out:
# 2026-03-23T16:38:56.578146Z

# %%
all_update_dates = {}

for item in data:
    date = item["created_at"]
    date = date.split("T")[0] + "T" + date.split("T")[1].split(":")[0] # Extract the date and hour part (YYYY-MM-DD-HH)
    if date in all_update_dates:
        all_update_dates[date] += 1
    else:
        all_update_dates[date] = 1

print(all_update_dates)
# Out:
# {'2026-03-23T16': 100}

# %%
import matplotlib.pyplot as plt
X = list(all_update_dates.keys())
X.sort()
Y = [all_update_dates[x] for x in X]
plt.bar(X, Y)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, '2026-04-19T15'),
#   Text(1, 0, '2026-04-19T16'),
#   Text(2, 0, '2026-04-19T17'),
#   Text(3, 0, '2026-04-19T18'),
#   Text(4, 0, '2026-04-19T20'),
#   Text(5, 0, '2026-04-19T21'),
#   Text(6, 0, '2026-04-19T22')])
